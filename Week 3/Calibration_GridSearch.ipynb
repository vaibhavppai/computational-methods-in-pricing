# %%
import warnings
warnings.filterwarnings("ignore")

import readPlotOptionSurface 
import modulesForCalibration as mfc

import numpy as np
#import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm
from cycler import cycler

#from mpl_toolkits.mplot3d import Axes3D
#from scipy import interpolate
#from scipy.stats import norm

# %%
# Parameters
alpha = 1.5
eta = 0.2
    
n = 12

# Model
model = 'Heston'

# risk free rate
r = 0.0245
# dividend rate
q = 0.005
# spot price
S0 = 190.3

# %%
maturities
# Out:
# array([ 25,  60,  88, 116, 151, 179, 333, 543, 697], dtype=int64)

# %%
maturities, strikes, callPrices = readPlotOptionSurface.readNPlot()

marketPrices = callPrices
maturities_years = maturities/365.0

# %% [markdown]
# ========================================
#
# Grid Search around the starting point
#
# ========================================
#
#  [ 2.3     0.046   0.0825 -0.53    0.054 ]

# %%
callPrices.shape
# Out:
# (9, 17)

# %%
len(strikes)
# Out:
# 17

# %%
ind_iter = 1
rmseMin = 1.0e6

for kappa in mfc.myRange(2.5,3.0,0.25):
    for theta in mfc.myRange(0.06,0.065,0.0025):
        for sig in mfc.myRange(0.1,0.3,0.05):
            for rho in mfc.myRange(-0.675,-0.625,0.025):
                for v0 in mfc.myRange(0.04,0.06,0.01):
                    params = []
                    params.append(kappa)
                    params.append(theta)
                    params.append(sig)
                    params.append(rho)
                    params.append(v0)
                    
                    print('i = ' + str(ind_iter))
                    ind_iter += 1
                    print(params)
                    rmse = mfc.eValue(params, marketPrices, maturities_years, strikes, r, q, S0, alpha, eta, n, model)
                    
                    if (rmse < rmseMin):
                        rmseMin = rmse
                        params2 = params
                        print('\nnew min found')
                        print(rmseMin)
                        print(params2)
                        print('')

print('\nSolution of grid search:')                        
print(params2)
print('Optimal rmse = ' + str(rmseMin))
# Out:
# i = 1
# [2.5, 0.06, 0.1, -0.675, 0.04]
#
# new min found
# 1.2279666265156184
# [2.5, 0.06, 0.1, -0.675, 0.04]
#
# i = 2
# [2.5, 0.06, 0.1, -0.675, 0.05]
# i = 3
# [2.5, 0.06, 0.1, -0.675, 0.060000000000000005]
# i = 4
# [2.5, 0.06, 0.1, -0.65, 0.04]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 19
#      17 ind_iter += 1
#      18 print(params)
# ---> 19 rmse = mfc.eValue(params, marketPrices, maturities_years, strikes, r, q, S0, alpha, eta, n, model)
#      21 if (rmse < rmseMin):
#      22     rmseMin = rmse
#
# File D:\Day One\MOOCs\Financial Engineering and Risk Management Specialization\C5 - Computational Methods in Pricing and Model Calibration\Week 3\modulesForCalibration.py:61, in eValue(params, *args)
#      59 T = maturities[i]
#      60 K = strikes[j]
# ---> 61 [km, cT_km] = genericFFT(params, S0, K, r, q, T, alpha, eta, n, model)
#      62 modelPrices[i,j] = cT_km[0]
#      63 tmp = marketPrices[i,j]-modelPrices[i,j]
#
# File D:\Day One\MOOCs\Financial Engineering and Risk Management Specialization\C5 - Computational Methods in Pricing and Model Calibration\Week 3\modulesForCalibration.py:159, in genericFFT(params, S0, K, r, q, T, alpha, eta, n, model)
#     156         wJ = eta
#     157     xX[j] = cmath.exp(-1j*beta*nuJ[j])*df*psi_nuJ[j]*wJ
# --> 159 yY = np.fft.fft(xX)
#     160 cT_km = np.zeros((N))
#     161 for i in range(N):
#
# File <__array_function__ internals>:200, in fft(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\numpy\fft\_pocketfft.py:215, in fft(a, n, axis, norm)
#     213     n = a.shape[axis]
#     214 inv_norm = _get_forward_norm(n, norm)
# --> 215 output = _raw_fft(a, n, axis, False, True, inv_norm)
#     216 return output
#
# File ~\anaconda3\Lib\site-packages\numpy\fft\_pocketfft.py:70, in _raw_fft(a, n, axis, is_real, is_forward, inv_norm)
#      67         a = z
#      69 if axis == a.ndim-1:
# ---> 70     r = pfi.execute(a, is_real, is_forward, fct)
#      71 else:
#      72     a = swapaxes(a, axis, -1)
#
# KeyboardInterrupt:

# %%
lenT = len(maturities)
lenK = len(strikes)
modelPrices = np.zeros((lenT, lenK))

for i in range(lenT):
    for j in range(lenK):
        T = maturities_years[i]
        K = strikes[j]
        [km, cT_km] = mfc.genericFFT(params2, S0, K, r, q, T, alpha, eta, n, model)
        modelPrices[i,j] = cT_km[0]


# plot
fig = plt.figure(figsize=(10,8))
labels = []
colormap = cm.Spectral
colors = [colormap(i) for i in np.linspace(0, 0.9, len(maturities))]

plt.gca().set_prop_cycle(cycler('color', colors))
for i in range(len(maturities)):
    plt.plot(strikes, callPrices[i,:], 'x')
    labels.append('T = ' + str(maturities[i]))
    
for i in range(len(maturities)):
    plt.plot(strikes, modelPrices[i,:], '+')
    labels.append('T = ' + str(maturities[i]))
plt.legend(labels, loc='upper right', ncol=2)
plt.grid(alpha=0.25)
plt.xlabel('Strike')
plt.ylabel('Price')
plt.title('Market vs. Model')
plt.savefig('MarketvsModel_GridSearch.png')
plt.show()
